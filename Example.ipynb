# %%
from main import run

# %%
df = run(True)
# Out:
# Opções:
# 1 - Homicídio Doloso
# 2 - Latrocínio
# 3 - Lesão Corporal Seguida de Morte
# 4 - Morte Decorrente de Oposição À Intervenção Policial
# 5 - Morte Suspeita
# 6 - Furto de Veículo
# 7 - Roubo de Veículo
# 8 - Furto de Celular
# 9 - Roubo de Celular
# Escolha a opção: 1
# Informe o ano  ( 2003 - 2018 ): 2018
# Informe o mês ( 1 - 12 ): 1
# ctl00$cphBody$lkMes1
# ctl00$cphBody$lkAno18
# ctl00$cphBody$btnHomicicio
# Extracting

# %%
df
# Out:
#        0     1          2                    3                    4   \
# 0    2018     1     1/2018  01/01/2018 01:26:11  01/01/2018 02:14:38
# 1    2018     7     7/2018  01/01/2018 04:38:35  01/01/2018 05:28:09
# 2    2018     7     7/2018  01/01/2018 06:15:58  01/01/2018 06:38:30
# 3    2018     1     1/2018  01/01/2018 03:36:02  01/01/2018 08:31:51
# 4    2018     1     1/2018  01/01/2018 03:36:02  01/01/2018 08:31:51
# 5    2018     1     1/2018  01/01/2018 03:36:02  01/01/2018 08:31:51
# 6    2018     1     1/2018  01/01/2018 03:36:02  01/01/2018 08:31:51
# 7    2018     1     1/2018  01/01/2018 03:36:02  01/01/2018 08:31:51
# 8    2018     1     1/2018  01/01/2018 03:36:02  01/01/2018 08:31:51
# 9    2018     1     1/2018  01/01/2018 03:36:02  01/01/2018 08:31:51
# 10   2018     1     1/2018  01/01/2018 03:36:02  01/01/2018 08:31:51
# 11   2018     1     1/2018  01/01/2018 03:36:02  01/01/2018 08:31:51
# 12   2018     1     1/2018  01/01/2018 03:36:02  01/01/2018 08:31:51
# ...
